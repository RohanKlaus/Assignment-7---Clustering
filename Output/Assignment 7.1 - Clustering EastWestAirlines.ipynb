# %% [markdown]
# # Clustering:

# %% [markdown]
# ### Problem Statement:

# %% [markdown]
# Perform clustering (hierarchical,K means clustering and DBSCAN) for the airlines data to obtain optimum number of clusters.
# Draw the inferences from the clusters obtained.
#
# **Data Description:**
#
# **Dataset: EastWestAirlines.xlsx**
#
# The file EastWestAirlinescontains information on passengers who belong to an airline’s frequent flier program. For each passenger the data include information on their mileage history and on different ways they accrued or spent miles in the last year. **The goal is to try to identify clusters of passengers that have similar characteristics for the purpose of targeting different segments for different types of mileage offers.**

# %% [markdown]
# ### Importing the required libraries:

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn import metrics
import seaborn as sns
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# ### Importing the dataset:

# %%
df = pd.read_csv("C:/Users/DELL/Desktop/ExcelR DS Assignments/Assignment 7 - Clustering/EastWestAirlines.csv")
df.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %% [markdown]
# ### Performing EDA:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
#Dropping irrelevant columns:

df1 = df.drop(['ID#','Award?'], axis=1)
df1.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll
# 0            1                  0                0               7000
# 1            2                  0                0               6968
# 2            4                  0                0               7034
# 3            1                  0                0               6952
# 4           26               2077                4               6935

# %%
# Checking missing values:

df1.isnull().sum()
# Out:
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# dtype: int64

# %%
df1.describe()
# Out:
#             Balance    Qual_miles    cc1_miles    cc2_miles    cc3_miles  \
# count  3.999000e+03   3999.000000  3999.000000  3999.000000  3999.000000
# mean   7.360133e+04    144.114529     2.059515     1.014504     1.012253
# std    1.007757e+05    773.663804     1.376919     0.147650     0.195241
# min    0.000000e+00      0.000000     1.000000     1.000000     1.000000
# 25%    1.852750e+04      0.000000     1.000000     1.000000     1.000000
# 50%    4.309700e+04      0.000000     1.000000     1.000000     1.000000
# 75%    9.240400e+04      0.000000     3.000000     1.000000     1.000000
# max    1.704838e+06  11148.000000     5.000000     3.000000     5.000000
#
#          Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# count    3999.000000   3999.00000        3999.000000      3999.000000
# mean    17144.846212     11.60190         460.055764         1.373593
# std     24150.967826      9.60381        1400.209171         3.793172
# ...

# %% [markdown]
# # DBSCAN:

# %%
df1.values
# Out:
# array([[28143,     0,     1, ...,     0,     0,  7000],
#        [19244,     0,     1, ...,     0,     0,  6968],
#        [41354,     0,     1, ...,     0,     0,  7034],
#        ...,
#        [73597,     0,     3, ...,     0,     0,  1402],
#        [54899,     0,     1, ...,   500,     1,  1401],
#        [ 3016,     0,     1, ...,     0,     0,  1398]], dtype=int64)

# %%
array_DBSCAN = df1.values
array_DBSCAN
# Out:
# array([[28143,     0,     1, ...,     0,     0,  7000],
#        [19244,     0,     1, ...,     0,     0,  6968],
#        [41354,     0,     1, ...,     0,     0,  7034],
#        ...,
#        [73597,     0,     3, ...,     0,     0,  1402],
#        [54899,     0,     1, ...,   500,     1,  1401],
#        [ 3016,     0,     1, ...,     0,     0,  1398]], dtype=int64)

# %% [markdown]
# ### Normalisation of Data:

# %%
stdscaler = StandardScaler()
X = stdscaler.fit_transform(array_DBSCAN)
X
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.28603258e-01, -3.62167870e-01,  1.39545434e+00],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.28603258e-01, -3.62167870e-01,  1.37995704e+00],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.28603258e-01, -3.62167870e-01,  1.41192021e+00],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.28603258e-01, -3.62167870e-01, -1.31560393e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#          2.85309024e-02, -9.85033311e-02, -1.31608822e+00],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.28603258e-01, -3.62167870e-01, -1.31754109e+00]])

# %%
dbscan = DBSCAN(eps=1.5, min_samples=8)
dbscan.fit(X)
# Out:
# DBSCAN(eps=1.5, min_samples=8)

# %%
#noisy samples are given label as -1

dbscan.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
df1['Cluster']=pd.DataFrame(dbscan.labels_)
df1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df1['Cluster'].value_counts()
# Out:
#  0    3681
# -1     286
#  1      22
#  2      10
# Name: Cluster, dtype: int64

# %%
#To find the percentage of the noise points

(len(df1[df1['Cluster']==-1])/len(df1))*100
# Out:
# 7.151787946986747

# %%
X = metrics.silhouette_score(X,dbscan.labels_)
X
# Out:
# 0.5715528877867831

# %%
def dbscan(X,eps,min_samples):
    ss=StandardScaler()
    X=ss.fit_transform(X)
    db=DBSCAN(eps=eps,min_samples=min_samples)
    db.fit(X)
    y_pred=db.fit_predict(X)
    plt.scatter(X[:,0],X[:,1],c=y_pred,cmap='Paired')
    plt.title("DBSCAN")

# %%
dbscan(array_DBSCAN,1.0,8)

# %% [markdown]
# # K-means:

# %%
df1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df2 = df1.drop(['Cluster'], axis=1)

# %%
df2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll
# ...

# %% [markdown]
# ### Normalisation of Data:

# %%
#Similar to the sklearn.preprocessing, StandardScaler function

def norm_func(i):
    x=(i-i.mean())/(i.std())
    return(x)

# %%
x=norm_func(df2.iloc[:,0:])
x
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.451084   -0.186275  -0.769482   -0.09823  -0.062759    -0.702698
# 1    -0.539389   -0.186275  -0.769482   -0.09823  -0.062759    -0.701001
# 2    -0.319991   -0.186275  -0.769482   -0.09823  -0.062759    -0.539185
# 3    -0.583726   -0.186275  -0.769482   -0.09823  -0.062759    -0.689200
# 4     0.239648   -0.186275   1.409295   -0.09823  -0.062759     1.082986
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.547010   -0.186275  -0.769482   -0.09823  -0.062759    -0.356915
# 3995 -0.091454   -0.186275  -0.769482   -0.09823  -0.062759    -0.669284
# 3996 -0.000043   -0.186275   0.683036   -0.09823  -0.062759     0.343761
# 3997 -0.185584   -0.186275  -0.769482   -0.09823  -0.062759    -0.689200
# 3998 -0.700420   -0.186275  -0.769482   -0.09823  -0.062759    -0.709903
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll
# ...

# %%
#Normalizaton Function

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

scaled_df2 = scaler.fit_transform(df2.iloc[:,0:])

# %%
scaled_df2
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.28603258e-01, -3.62167870e-01,  1.39545434e+00],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.28603258e-01, -3.62167870e-01,  1.37995704e+00],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.28603258e-01, -3.62167870e-01,  1.41192021e+00],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.28603258e-01, -3.62167870e-01, -1.31560393e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#          2.85309024e-02, -9.85033311e-02, -1.31608822e+00],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.28603258e-01, -3.62167870e-01, -1.31754109e+00]])

# %%
#wcss = Within Clusters Sum of Squares

wcss = []
for i in range(2,10):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(scaled_df2)
    wcss.append(kmeans.inertia_)
    
print(wcss)

plt.plot(range(2,10),wcss)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# [32088.27969959076, 27558.76517568194, 23807.810658831684, 20348.78522308945, 17724.875828973665, 15871.129769316563, 14359.144831709315, 13228.036693755905]

# %%
#Build Cluster Algorithm

from sklearn.cluster import KMeans
clusters_new = KMeans(3,random_state=0)
clusters_new.fit(x)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
clusters_new.labels_
# Out:
# array([2, 2, 2, ..., 2, 2, 2])

# %%
#Assign clusters to new dataset

df2['Clustered_new']=clusters_new.labels_

# %%
df2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
#These are the standardised values: 

clusters_new.cluster_centers_
# Out:
# array([[ 1.24892952,  0.82918409,  0.08882387,  0.14805264,  0.09244978,
#          0.64835933,  1.63425439,  3.50370508,  3.81124506,  0.30843599],
#        [ 0.41554258, -0.00710859,  1.18574734, -0.08815858,  0.10098914,
#          0.90202365,  0.74679497, -0.10240531, -0.11299565,  0.34245125],
#        [-0.30734357, -0.05112669, -0.64663966,  0.03782427, -0.06070092,
#         -0.53041426, -0.51188879, -0.17692897, -0.19159353, -0.20549974]])

# %%
df2.groupby('Clustered_new').agg(['mean']).reset_index()
# Out:
#   Clustered_new        Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                           mean        mean      mean      mean      mean
# 0             0  199463.030303  785.624242  2.181818  1.036364  1.030303
# 1             1  115619.195086  138.821296  3.694713  1.001489  1.032018
# 2             2   42610.891208  104.475713  1.169811  1.020072  1.000401
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0  32803.351515   27.296970       5365.975758       15.830303
# 1  38969.262844   18.758004        317.138496        0.946389
# 2   4341.215175    6.704135        212.147732        0.646327
#
#   Days_since_enroll
#                mean
# 0       4755.521212
# 1       4830.054356
# 2       3692.771979

# %%
df2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df2['Clustered_new']=df2['Clustered_new'].replace(0,'Cluster1')
df2['Clustered_new']=df2['Clustered_new'].replace(1,'Cluster2')
df2['Clustered_new']=df2['Clustered_new'].replace(2,'Cluster3')
df2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df2.columns
# Out:
# Index(['Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Clustered_new'],
#       dtype='object')

# %%
df2['Clustered_new'].value_counts()
# Out:
# Cluster3    2491
# Cluster2    1343
# Cluster1     165
# Name: Clustered_new, dtype: int64

# %%
df2.groupby('Clustered_new').mean()
# Out:
#                      Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# Clustered_new
# Cluster1       199463.030303  785.624242   2.181818   1.036364   1.030303
# Cluster2       115619.195086  138.821296   3.694713   1.001489   1.032018
# Cluster3        42610.891208  104.475713   1.169811   1.020072   1.000401
#
#                 Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# Clustered_new
# Cluster1       32803.351515    27.296970        5365.975758        15.830303
# Cluster2       38969.262844    18.758004         317.138496         0.946389
# Cluster3        4341.215175     6.704135         212.147732         0.646327
#
#                Days_since_enroll
# Clustered_new
# Cluster1             4755.521212
# Cluster2             4830.054356
# Cluster3             3692.771979

# %% [markdown]
# ## Hierarchical Clustering:

# %%
df1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df3 = df1.drop(['Cluster'], axis=1)
df3
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll
# ...

# %% [markdown]
# ### Normalisation of Data:

# %%
#Normalization Function : (MinMax Function)

def minmax_func(i):
    x= (i-i.min())/(i.max()-i.min())
    return(x)

# %%
#Normalized data frame (considering the numerical part of data)

df_norm = minmax_func(df3.iloc[:,0:])

# %%
df_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll
# ...

# %%
#create dendrogram

dendrogram = sch.dendrogram(sch.linkage(df_norm,method='complete'))

#methods : 'single','complete','centroid','average'

# %%
#create clusters

hc = AgglomerativeClustering(n_clusters=3, affinity = 'euclidean', linkage = 'complete')
hc
# Out:
# AgglomerativeClustering(linkage='complete', n_clusters=3)

# %%
#save clusters for chart

y_hc = hc.fit_predict(df_norm)
y_hc
# Out:
# array([2, 2, 2, ..., 0, 2, 2], dtype=int64)

# %%
Clusters = pd.DataFrame(y_hc, columns=['Clusters'])

# %%
Clusters
# Out:
#       Clusters
# 0            2
# 1            2
# 2            2
# 3            2
# 4            0
# ...        ...
# 3994         2
# 3995         2
# 3996         0
# 3997         2
# 3998         2
#
# [3999 rows x 1 columns]

# %%
Clusters.value_counts()
# Out:
# Clusters
# 2           2605
# 0           1390
# 1              4
# dtype: int64

# %%
df3['h_clustered']=y_hc
df3
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df3.groupby('h_clustered').mean()
# Out:
#                    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# h_clustered
# 0            107121.805755  148.161151   3.666906   1.001439   1.033094
# 1            131999.500000  347.000000   2.500000   1.000000   1.000000
# 2             55625.489827  141.643762   1.201152   1.021497   1.001152
#
#               Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# h_clustered
# 0            38980.861151    18.749640         476.129496         1.424460
# 1            65634.250000    69.250000       19960.000000        49.250000
# 2             5418.927447     7.699424         421.536660         1.272937
#
#              Days_since_enroll
# h_clustered
# 0                  4185.129496
# 1                  2200.250000
# 2                  4085.983877
